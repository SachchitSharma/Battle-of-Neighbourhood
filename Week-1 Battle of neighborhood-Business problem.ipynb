# %% [markdown]
# # The Battle of Neighborhoods (Week 1)

# %% [markdown]
# In this notebook we will explore the city of brussels and try to decide upon the marketing stretegy for ABC telecommunications consumer plans.

# %% [markdown]
# ## Introduction

# %% [markdown]
# ABC telecom company is a well established telecom companey in belgium. it wants to increase ite presence in  Brussels area. In brussels companey presence is relatively low. for that companey wants to decide upon the marketing stretegy for its plans in different parts of brussels as it seems suitable after analysis.

# %% [markdown]
# ## Business Problem

# %% [markdown]
# ABC telecom company is a well established telecom companey in belgium. it wants to increase ite presence in  Brussels area. In brussels companey presence is relatively low. Company has segmented its plans in below catagories
# <ul>
#     <li> Highend family Plans </li>
#     <li> Economical family Plans </li>
#     <li> Highend individual Plans </li>
#     <li> Economical individual Plans </li>
#     <li> Traveller Plans </li>
#     <li> Sports Packages </li>
# </ul>
# Brussels is the capital of belgium having 19 sub municipalities. Company  wants insight into the neighborhoods and local businesses in the cities living standards,  quality of life and target audience in that perticular area. This project will explore the similarities and dissimilarities between  neighborhoods in the  city, and determine which neighborhoods fits for which plan segment of the companey and that will help to finalise the marketing stretegy of the company.

# %% [markdown]
# ## Target audience

# %% [markdown]
# Business analysits,  Business stake holders, etailers
